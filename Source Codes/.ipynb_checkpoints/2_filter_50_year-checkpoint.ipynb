# %%
import pandas as pd

# %%
raw_data = pd.read_csv('/Users/alan/Desktop/hottest_50_1960_2022_encoding.csv')

# %%
raw_data.head()
# Out:
#          date                title                            artist  rank  \
# 0  1960-04-18         Running Bear                    Johnny Preston    91
# 1  1960-11-07  Finger Poppin' Time  Hank Ballard And The Midnighters    69
# 2  1960-02-15       Mack The Knife                       Bobby Darin    76
# 3  1960-05-30       Sweet Nothin's                        Brenda Lee    63
# 4  1960-07-11      Sixteen Reasons                    Connie Stevens    61
#
#   last_week  peak  weeks  year  danceability  energy  ...  mode  speechiness  \
# 0        81     1     27  1960         0.610   0.688  ...   1.0       0.0357
# 1        57     7     26  1960           NaN     NaN  ...   NaN          NaN
# 2        59     1     26  1960         0.549   0.529  ...   0.0       0.1080
# 3        32     4     24  1960           NaN     NaN  ...   NaN          NaN
# 4        40     3     24  1960         0.339   0.406  ...   1.0       0.0319
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.573          0.000000     0.164    0.761  119.831     165893.0
# 1           NaN               NaN       NaN      NaN      NaN          NaN
# 2         0.760          0.000000     0.206    0.464   82.755     184333.0
# 3           NaN               NaN       NaN      NaN      NaN          NaN
# 4         0.865          0.000011     0.110    0.619  109.783     118133.0
#
#                                               genres  genre_encoding
# 0                                ['nashville sound']             NaN
# 1                                                 []             NaN
# 2  ['adult standards', 'brill building pop', 'eas...            rock
# 3                                                 []             NaN
# 4                           ['deep adult standards']             NaN
#
# [5 rows x 22 columns]

# %%
raw_data = raw_data.sort_values('weeks', ascending = False)
raw_data.dorp
# Out:
#             date                           title           artist  rank  \
# 3050  2021-09-04                 Blinding Lights       The Weeknd    20
# 2700  2014-05-10                     Radioactive  Imagine Dragons    49
# 2701  2014-03-22                            Sail       AWOLNATION    45
# 2450  2009-10-10                       I'm Yours       Jason Mraz    48
# 3100  2022-04-02                      Levitating         Dua Lipa    16
# ...          ...                             ...              ...   ...
# 291   1965-07-31      A Walk In The Black Forest  Horst Jankowski    35
# 290   1965-01-16               Oh No Not My Baby     Maxine Brown    39
# 289   1965-08-07  Laurie (Strange Things Happen)       Dickey Lee    46
# 287   1965-09-25           Down In The Boondocks  Billy Joe Royal    49
# 288   1965-02-06                        The Jerk        The Larks    33
#
#      last_week  peak  weeks  year  danceability  energy  ...  mode  \
# 3050        21     1     90  2021         0.514   0.730  ...   1.0
# 2700        48     3     87  2014         0.448   0.784  ...   1.0
# 2701        41    17     79  2014         0.826   0.436  ...   1.0
# 2450        49     6     76  2009           NaN     NaN  ...   NaN
# 3100        19     2     72  2022         0.702   0.825  ...   0.0
# ...        ...   ...    ...   ...           ...     ...  ...   ...
# 291         29    12     13  1965         0.659   0.717  ...   1.0
# 290         37    24     13  1965         0.770   0.896  ...   1.0
# 289         21    14     13  1965         0.687   0.350  ...   1.0
# 287         30     9     13  1965         0.582   0.831  ...   1.0
# 288         16     7     13  1965         0.280   0.993  ...   1.0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 3050       0.0598       0.00146          0.000095    0.0897    0.334  171.005
# 2700       0.0627       0.10600          0.000108    0.6680    0.236  136.245
# 2701       0.0558       0.44100          0.615000    0.0964    0.272  119.051
# 2450          NaN           NaN               NaN       NaN      NaN      NaN
# 3100       0.0601       0.00883          0.000000    0.0674    0.915  102.977
# ...           ...           ...               ...       ...      ...      ...
# 291        0.0318       0.33100          0.911000    0.1270    0.384  139.952
# 290        0.0390       0.05390          0.000000    0.2430    0.964  126.999
# 289        0.0344       0.62300          0.000000    0.0861    0.435  119.508
# 287        0.0494       0.45700          0.000339    0.1700    0.722  147.981
# 288        0.2830       0.00185          0.000000    0.3320    0.310  143.049
#
#       duration_ms                                             genres  \
# 3050     200040.0  ['canadian contemporary r&b', 'canadian pop', ...
# 2700     186813.0                            ['modern rock', 'rock']
# 2701     259093.0  ['la indie', 'modern alternative rock', 'moder...
# 2450          NaN                                                 []
# 3100     203064.0                     ['dance pop', 'pop', 'uk pop']
# ...           ...                                                ...
# 291      316919.0  ['chillwave', 'downtempo', 'electronica', 'ind...
# 290      182587.0  ['dance pop', 'electropop', 'metropopolis', 'p...
# 289      186693.0                                                 []
# 287       95493.0                       ['hollywood', 'movie tunes']
# 288      106147.0  ['alternative emo', 'dreamo', 'emo', 'indie ga...
#
#       genre_encoding
# 3050             pop
# 2700            rock
# 2701            rock
# 2450             NaN
# 3100             pop
# ...              ...
# 291              NaN
# 290              pop
# 289              NaN
# 287              NaN
# 288             rock
#
# [3150 rows x 22 columns]

# %%
hotest = pd.DataFrame(columns = raw_data.columns)
data_group = raw_data.groupby('year')
for year in data_group:
    this_year = year[1].sort_values('weeks', ascending = False)
    this_year = this_year[['title', 'artist', 'weeks']]
    this_year.drop_duplicates(['title', 'artist'], inplace = True)
    this_year_index = this_year.index[0:50]
    hotest = hotest.append(raw_data.iloc[this_year_index])

# %%
hotest = hotest.reset_index(drop = True)
